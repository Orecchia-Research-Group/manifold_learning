# %%
import numpy as np
from pymanopt.manifolds import Sphere

import matplotlib.pyplot as plt
from statsmodels.graphics.tsaplots import plot_acf
from mpl_toolkits.mplot3d import Axes3D
import scipy.ndimage

import mala.utils as my
import mala.potentials
import mala.metropolis_hastings as vanilla_mh
import mala.MA_metropolis_hastings as mamh
import mala.icosehedron as ico

# %matplotlib inline

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
H = mala.potentials.Spherical(ambient_dim=3,proper_dim=2)
face_graph,vertex_graph,face_dict = ico.generate_icosahedron()

# %%
test_face = face_dict[list(face_graph.nodes())[0]]

# %%
test_face.circumcircle_radius
# Out:
# 1.1547005383792517

# %%
# %matplotlib inline
T = 100
# note: our faces' circumcircle is about 1.15, so we want our step size
# to be small relative to that
step_size = 0.1

trajectory = mamh.ico_MAMH(H,T,step_size)
# Out:
# left our face
#      previous coors [0.26674893 0.47963636]
#      next coors in this face [0.33176656 0.52640531]
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-99-29feb8082219> in <module>()
#       5 step_size = 0.1
#       6
# ----> 7 trajectory = mamh.ico_MAMH(H,T,step_size)
#
# ~/Documents/GitHub/manifold_learning/manifold_sampling/mala/MA_metropolis_hastings.py in ico_MAMH(H, max_steps, step_size, **kwargs)
#     105                         # find the next face we'll move to
#     106 			next_face_node = ico.face_across_edge(x.face_obj,x.face_coors,
# --> 107 				face_graph)
#     108                         next_face_obj = face_dict[next_face_node]
#     109
#
# ~/Documents/GitHub/manifold_learning/manifold_sampling/mala/icosehedron.py in face_across_edge(face, side_crossings, face_graph)
#     376     faces adjacent to the original face in face_graph
#     377     """
# --> 378     assert np.sum(side_crossings)==1
#     379     # first, ID the edge we're traversing using a pair of vertices
#     380     face_verts = (face.v_1.name,face.v_2.name,face.v_3.name)
#
# AssertionError:

# %%
# %matplotlib notebook
my.plot_on_icosahedron(H,trajectory)
# Out:
# <img src="data:image/png;base64,..." width="699.444462973395">
