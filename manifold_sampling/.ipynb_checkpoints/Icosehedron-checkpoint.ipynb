# %%
import numpy as np
from pymanopt.manifolds import Sphere
import matplotlib.pyplot as plt
import mala.potentials
import mala.metropolis_hastings as mh
import mala.icosehedron as ico
from mpl_toolkits.mplot3d import Axes3D

# %matplotlib notebook

# %load_ext autoreload
# %autoreload 2

phi = (1 + 5 ** 0.5) / 2

# %% [markdown]
# # Generate vertices via G

# %%
G = ico.generate_G(verbose=False)
V = ico.generate_V(G)

# %%
fig = plt.figure(figsize=(7,7))
ax = fig.add_subplot(111, projection='3d')

for idx,v in enumerate(V):
    ax.scatter(v.p[0],v.p[1],v.p[2],label=str(idx))
    
plt.legend()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="699.444462973395">

# %%
fig = plt.figure(figsize=(10,10))
ax = fig.add_subplot(111, projection='3d')

for idx,v in enumerate(V):
    ax.scatter(v.p[0],v.p[1],v.p[2],marker='.',color='g')
    
top_face = ico.face(V[3],V[5],V[8])

f_0 = top_face.return_coors()
f_1 = top_face.coor_shift_by_g(G[6])

face_list = [f_0]
marker_list = ['o','x']
color_list = ['b','r']
for f_idx,f in enumerate(face_list):
    for v_idx,p in enumerate(f):
        ax.scatter(p[0],p[1],p[2],marker=marker_list[f_idx],
                   color=color_list[f_idx],
                   label=str(v_idx))
        
ax.scatter(top_face.ctd_coors[0],top_face.ctd_coors[1],top_face.ctd_coors[2],color='c')
ax.quiver(top_face.ctd_coors[0],top_face.ctd_coors[1],top_face.ctd_coors[2],
         top_face.basis_1[0],top_face.basis_1[1],top_face.basis_1[2])
plt.legend()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="999.4444709206812">

# %%
fig = plt.figure(figsize=(10,10))
ax = fig.add_subplot(111, projection='3d')

for idx,v in enumerate(V):
    ax.scatter(v.p[0],v.p[1],v.p[2],marker='.',color='g')
    
top_face = ico.face(V[3],V[5],V[8])

f_0 = top_face.return_coors()

face_list = [f_0]
marker_list = ['o','x']
color_list = ['b','r']
for f_idx,f in enumerate(face_list):
    for v_idx,p in enumerate(f):
        ax.scatter(p[0],p[1],p[2],marker=marker_list[f_idx],
                   color=color_list[f_idx],
                   label=str(v_idx))
        
ax.scatter(top_face.ctd_coors[0],top_face.ctd_coors[1],top_face.ctd_coors[2],color='c')
ax.quiver(top_face.ctd_coors[0],top_face.ctd_coors[1],top_face.ctd_coors[2],
         top_face.basis_1[0],top_face.basis_1[1],top_face.basis_1[2])


c_prime,v_prime = ico.chart_coors(top_face.ctd_coors,top_face)

plt.legend()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="999.4444709206812">

# %% [markdown]
# # List of transformations that preserve edges
#
# G_6

# %%
fig = plt.figure(figsize=(7,7))
ax = fig.add_subplot(111, projection='3d')

for idx,v in enumerate(V):
    ax.scatter(v.p[0],v.p[1],v.p[2],marker='.',color='g')
    
top_face = ico.face(V[6],V[7],V[4])

f_0 = top_face.return_coors()
f_1 = top_face.coor_shift_by_g(G[22])

face_list = [f_0,f_1]
marker_list = ['o','x']
color_list = ['b','r']
for f_idx,f in enumerate(face_list):
    for v_idx,p in enumerate(f):
        ax.scatter(p[0],p[1],p[2],marker=marker_list[f_idx],
                   label=str(v_idx))

plt.legend()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="699.444462973395">
